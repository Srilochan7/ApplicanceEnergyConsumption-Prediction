# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('energydata_complete.csv')

# %%
df.head()
# Out:
#   recorded_timestamp  total_energy_use  lighting_energy_use  temp_sensor_1  \
# 0   11-01-2016 17:00                60                   30          19.89
# 1   11-01-2016 17:10                60                   30          19.89
# 2   11-01-2016 17:20                50                   30          19.89
# 3   11-01-2016 17:30                50                   40          19.89
# 4   11-01-2016 17:40                60                   40          19.89
#
#    humidity_sensor_1  temp_sensor_2  humidity_sensor_2  temp_sensor_3  \
# 0          47.596667           19.2          44.790000          19.79
# 1          46.693333           19.2          44.722500          19.79
# 2          46.300000           19.2          44.626667          19.79
# 3          46.066667           19.2          44.590000          19.79
# 4          46.333333           19.2          44.530000          19.79
#
#    humidity_sensor_3  temp_sensor_4  ...  Unnamed: 32  Unnamed: 33  \
# ...

# %%
df.isnull().sum()
# Out:
# recorded_timestamp          0
# total_energy_use            0
# lighting_energy_use         0
# temp_sensor_1               0
# humidity_sensor_1           0
# temp_sensor_2               0
# humidity_sensor_2           0
# temp_sensor_3               0
# humidity_sensor_3           0
# temp_sensor_4               0
# humidity_sensor_4           0
# temp_sensor_5               0
# humidity_sensor_5           0
# temp_sensor_6               0
# humidity_sensor_6           0
# temp_sensor_7               0
# humidity_sensor_7           0
# temp_sensor_8               0
# humidity_sensor_8           0
# temp_sensor_9               0
# humidity_sensor_9           0
# external_temp               0
# atmospheric_pressure        0
# external_humidity           0
# wind_speed_mps              0
# visibility_km               0
# dew_point_temp              0
# random_variable_1           0
# random_variable_2           0
# Unnamed: 29             19735
# Unnamed: 30             19735
# ...

# %%
df.drop(['Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
         'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
         'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
         'Unnamed: 41'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# recorded_timestamp      0
# total_energy_use        0
# lighting_energy_use     0
# temp_sensor_1           0
# humidity_sensor_1       0
# temp_sensor_2           0
# humidity_sensor_2       0
# temp_sensor_3           0
# humidity_sensor_3       0
# temp_sensor_4           0
# humidity_sensor_4       0
# temp_sensor_5           0
# humidity_sensor_5       0
# temp_sensor_6           0
# humidity_sensor_6       0
# temp_sensor_7           0
# humidity_sensor_7       0
# temp_sensor_8           0
# humidity_sensor_8       0
# temp_sensor_9           0
# humidity_sensor_9       0
# external_temp           0
# atmospheric_pressure    0
# external_humidity       0
# wind_speed_mps          0
# visibility_km           0
# dew_point_temp          0
# random_variable_1       0
# random_variable_2       0
# dtype: int64

# %%
df['recorded_timestamp'] = pd.to_datetime(df['recorded_timestamp'], dayfirst=True)
df.set_index('recorded_timestamp', inplace=True)

# %%
df.head()
# Out:
#                      total_energy_use  lighting_energy_use  temp_sensor_1  \
# recorded_timestamp
# 2016-01-11 17:00:00                60                   30          19.89
# 2016-01-11 17:10:00                60                   30          19.89
# 2016-01-11 17:20:00                50                   30          19.89
# 2016-01-11 17:30:00                50                   40          19.89
# 2016-01-11 17:40:00                60                   40          19.89
#
#                      humidity_sensor_1  temp_sensor_2  humidity_sensor_2  \
# recorded_timestamp
# 2016-01-11 17:00:00          47.596667           19.2          44.790000
# 2016-01-11 17:10:00          46.693333           19.2          44.722500
# 2016-01-11 17:20:00          46.300000           19.2          44.626667
# 2016-01-11 17:30:00          46.066667           19.2          44.590000
# 2016-01-11 17:40:00          46.333333           19.2          44.530000
#
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
df['total_energy_use'].plot()
plt.title("Total energy use over time")
plt.ylabel("Energy use")
plt.xlabel("Time")
plt.grid(True)
plt.show()

# %%
import seaborn as sns

# Compute correlation matrix
corr_matrix = df.corr()

# Plot heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Correlation Heatmap of Features")
plt.show()
